# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk

# Use this instead
df = pd.read_csv('The FINAL Dataset.csv')
display(df)
# Out:
#           county    state  cases  deaths  2020 population  2019 raw GDP  \
# 0        Autauga  Alabama   4190    48.0          58877.0     1540762.0
# 1        Baldwin  Alabama  13601   161.0         233140.0     7134734.0
# 2        Barbour  Alabama   1514    32.0          25180.0      729105.0
# 3           Bibb  Alabama   1834    46.0          22223.0      380453.0
# 4         Blount  Alabama   4641    63.0          59081.0      932215.0
# ...          ...      ...    ...     ...              ...           ...
# 3240  Sweetwater  Wyoming   2966    16.0          42158.0     3677972.0
# 3241       Teton  Wyoming   2138     4.0          23347.0     2268742.0
# 3242       Uinta  Wyoming   1558     7.0          20441.0      881052.0
# 3243    Washakie  Wyoming    780    19.0           7658.0      349686.0
# 3244      Weston  Wyoming    476     2.0           6809.0      322576.0
#
#       percent change 2020
# 0                    -1.3
# 1                    -2.1
# ...

# %% [markdown]
# This log scaling of the # of cases was added after noticing outliers in the data.

# %%
df['cases_log'] = np.log10(df['cases'] + 1)
df.hist(column='cases_log')
# Out:
# array([[<AxesSubplot:title={'center':'cases_log'}>]], dtype=object)

# %%
corr = df.corr()
corr.style.format(precision = 4)
#sns.heatmap(tips_df.corr(), annot = True)
sns.heatmap(corr, annot = True, cmap = 'coolwarm', square = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

plt.scatter(df['cases_log'], df['percent change 2020'], s = 1)

# %%
df['cases_rate'] = df['cases']/df['2020 population']
df.hist(column='cases_rate')

# %%
plt.xlim(0, 0.15)
plt.ylim(-20, 20)
plt.scatter(df['cases_rate'], df['percent change 2020'], s = 1)
